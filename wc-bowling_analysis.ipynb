# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('icc_wc_23_bowl.csv')

# %%
df.isna().sum()
# Out:
# player      0
# overs       0
# maidens     0
# runs        0
# wickets     0
# run_rate    0
# 0s          0
# 4s          0
# 6s          0
# wd          0
# nb          0
# team        0
# opponent    0
# innings     0
# match_id    0
# dtype: int64

# %%
df
# Out:
#                   player  overs  maidens  runs  wickets  run_rate  0s  4s  6s  \
# 0     Dilshan Madushanka   10.0        0    80        5      8.00  25   8   2
# 1    Dushmantha Chameera   10.0        2    71        1      7.10  28   8   2
# 2          Kasun Rajitha    9.0        0    65        0      7.22  25   7   2
# 3         Angelo Mathews    3.0        0    11        0      3.66  10   1   0
# 4     Maheesh Theekshana   10.0        0    67        0      6.70  18   5   1
# ..                   ...    ...      ...   ...      ...       ...  ..  ..  ..
# 569         David Willey   10.0        0    56        3      5.60  37   8   1
# 570         Chris Woakes    5.3        0    27        1      4.90  22   5   0
# 571          Adil Rashid   10.0        0    55        2      5.50  26   4   1
# 572         Gus Atkinson    8.0        0    45        2      5.62  29   3   3
# 573            Moeen Ali   10.0        0    60        2      6.00  27   7   1
#
#      wd  nb       team  opponent  innings  match_id
# 0     6   0  Sri Lanka     India        1         0
# 1     0   0  Sri Lanka     India        1         0
# 2     1   0  Sri Lanka     India        1         0
# 3     0   0  Sri Lanka     India        1         0
# 4     1   0  Sri Lanka     India        1         0
# ..   ..  ..        ...       ...      ...       ...
# 569   2   0    England  Pakistan        2        47
# 570   0   0    England  Pakistan        2        47
# 571   1   0    England  Pakistan        2        47
# 572   2   0    England  Pakistan        2        47
# 573   0   0    England  Pakistan        2        47
#
# [574 rows x 15 columns]

# %%
df.player.value_counts()
# Out:
# player
# Ravindra Jadeja        11
# Kuldeep Yadav          11
# Adam Zampa             11
# Mohammed Siraj         11
# Jasprit Bumrah         11
#                        ..
# Ravichandran Ashwin     1
# Sean Abbott             1
# Ryan Klein              1
# Tanzim Hasan Sakib      1
# Shariz Ahmad            1
# Name: count, Length: 102, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   player    574 non-null    object
#  1   overs     574 non-null    float64
#  2   maidens   574 non-null    int64
#  3   runs      574 non-null    int64
#  4   wickets   574 non-null    int64
#  5   run_rate  574 non-null    float64
#  6   0s        574 non-null    int64
#  7   4s        574 non-null    int64
#  8   6s        574 non-null    int64
#  9   wd        574 non-null    int64
#  10  nb        574 non-null    int64
#  11  team      574 non-null    object
#  12  opponent  574 non-null    object
#  13  innings   574 non-null    int64
#  14  match_id  574 non-null    int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 67.4+ KB

# %%
df.describe()
# Out:
#             overs     maidens        runs     wickets    run_rate          0s  \
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     7.351045    0.256098   42.322300    1.202091    5.922369   22.918118
# std      2.685601    0.533933   19.651473    1.193757    2.135935   10.251561
# min      0.300000    0.000000    1.000000    0.000000    1.350000    0.000000
# 25%      6.000000    0.000000   30.000000    0.000000    4.500000   16.000000
# 50%      8.000000    0.000000   41.000000    1.000000    5.660000   24.000000
# 75%     10.000000    0.000000   55.000000    2.000000    7.075000   30.000000
# max     10.000000    3.000000  115.000000    7.000000   16.000000   48.000000
#
#                4s          6s          wd          nb     innings    match_id
# count  574.000000  574.000000  574.000000  574.000000  574.000000  574.000000
# mean     3.900697    1.121951    1.158537    0.097561    1.480836   23.691638
# std      2.599953    1.302075    1.535259    0.330362    0.500068   13.858070
# min      0.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000   12.000000
# 50%      4.000000    1.000000    1.000000    0.000000    1.000000   24.000000
# 75%      5.000000    2.000000    2.000000    0.000000    2.000000   36.000000
# max     15.000000    6.000000   10.000000    2.000000    2.000000   47.000000

# %%
# function to get the stats of highest runs, wickets, 4s ,6s, maiden in one match of the tournament. 

def maxInOneMatch(req):
    
    # retrieve the max row according to required subject.
    max_row = df.loc[df[req].idxmax()]
    
    player = max_row['player']
    team = max_row['team']
    req = max_row[req]
    opponent = max_row['opponent']

    return {
        'player':player,
        'team':team,
        'req':req,
        'opponent':opponent
    }

# %% [markdown]
# # Highest run given by which player in one match?

# %%
max_runs = maxInOneMatch('runs')
print(f"Highest runs conceded by {max_runs['player']} from {max_runs['team']} in one of the matches which was {max_runs['req']} runs against {max_runs['opponent']}. ")
# Out:
# Highest runs conceded by Bas de Leede from Netherlands in one of the matches which was 115 runs against Australia.

# %% [markdown]
# # Highest wicket taken by which player in one match?

# %%
max_wickets = maxInOneMatch('wickets')
print(f"Highest wickets taken by {max_wickets['player']} from {max_wickets['team']} in one of the matches which was {max_wickets['req']} wickets against {max_wickets['opponent']}. ")
# Out:
# Highest wickets taken by Mohammed Shami from India in one of the matches which was 7 wickets against New Zealand.

# %% [markdown]
# # Highest 4's given by which player in one match?

# %%
max_4s = maxInOneMatch('4s')
print(f"Highest 4s conceded by {max_4s['player']} from {max_4s['team']} in one of the matches which was {max_4s['req']} 4s against {max_4s['opponent']}. ")
# Out:
# Highest 4s conceded by Marco Jansen from South Africa in one of the matches which was 15 4s against India.

# %% [markdown]
# # Highest 6's given by which player in one match?

# %%
max_6s = maxInOneMatch('6s')
print(f"Highest 6s conceded by {max_6s['player']} from {max_6s['team']} in one of the matches which was {max_6s['req']} 6s against {max_6s['opponent']}. ")
# Out:
# Highest 6s conceded by Hasan Mahmud from Bangladesh in one of the matches which was 6 6s against South Africa.

# %% [markdown]
# # Highest maidens bowled by which player in one match?

# %%
max_maidens = maxInOneMatch('maidens')
print(f"Highest maidens bowled by {max_maidens['player']} from {max_maidens['team']} in one of the matches which was {max_maidens['req']} maidens against {max_maidens['opponent']}. ")
# Out:
# Highest maidens bowled by Trent Boult from New Zealand in one of the matches which was 3 maidens against Sri Lanka.

# %% [markdown]
# # Highest wicket taker of the tournament?

# %%
wicket_takers = df.groupby('player')['wickets'].sum().sort_values(ascending=False).reset_index()
print(f"Highest wicket taker was {wicket_takers.iloc[0].player}, he took {wicket_takers.iloc[0].wickets} wickets.")
# Out:
# Highest wicket taker was Mohammed Shami, he took 24 wickets.

# %% [markdown]
# # Top 5 highest wicket takers?

# %%
top_five = wicket_takers[:5]
plt.figure(figsize=(10,5))
sns.barplot(data=top_five, x='player', y='wickets', palette='viridis')
plt.title('Top 5 highest wicket takers')
plt.xlabel('Players')
plt.ylabel('Wickets')
plt.show()

# %%
# group plyers by overs, runs, wickets, maiden, run-rates..........
df_player_overs = df.groupby('player').agg({'overs':'sum', 'maidens':'sum', 'runs':'sum', 'wickets':'sum','run_rate':'mean', '4s':'sum', '6s':'sum', 'wd':'sum'})

# %%
df_players = df_player_overs.sort_values(by='overs', ascending=False).reset_index()

# %%
df_players
# Out:
#                     player  overs  maidens  runs  wickets   run_rate  4s  6s  \
# 0               Adam Zampa   96.0        1   515       23   5.290909  33  14
# 1            Kuldeep Yadav   95.1        2   424       15   4.077273  21  14
# 2           Josh Hazlewood   93.1        8   449       16   4.741818  49   8
# 3          Ravindra Jadeja   92.9        4   398       16   4.362727  25   9
# 4         Mitchell Santner   92.4        4   449       16   4.958000  24  14
# ..                     ...    ...      ...   ...      ...        ...  ..  ..
# 97          Daryl Mitchell    1.3        0    12        0   6.500000   0   1
# 98        Charith Asalanka    1.0        0    10        0  10.000000   1   0
# 99             Rahmat Shah    1.0        0    12        0  12.000000   1   1
# 100  Najmul Hossain Shanto    1.0        0     5        0   5.000000   1   0
# 101           Rohit Sharma    0.5        0     7        1   8.400000   0   1
#
#      wd
# 0     9
# 1     4
# 2    13
# 3     2
# 4     5
# ..   ..
# 97    0
# 98    0
# 99    0
# 100   0
# 101   0
#
# [102 rows x 9 columns]

# %% [markdown]
# # Top 10 bowlers with best economy rate & have bowled atleast 50 overs?

# %%
temp = df_players[df_players['overs']>=50].sort_values(by='run_rate').reset_index()
best_economy = temp[:10]

# %%
best_economy
# Out:
#    index            player  overs  maidens  runs  wickets  run_rate  4s  6s  \
# 0      5    Jasprit Bumrah   91.5        9   373       20  3.874545  38   6
# 1      1     Kuldeep Yadav   95.1        2   424       15  4.077273  21  14
# 2      3   Ravindra Jadeja   92.9        4   398       16  4.362727  25   9
# 3     10       Rashid Khan   86.3        2   388       11  4.548889  25   4
# 4      2    Josh Hazlewood   93.1        8   449       16  4.741818  49   8
# 5     31     Mohammad Nabi   61.3        4   254        8  4.868889  16   7
# 6      7    Keshav Maharaj   89.0        1   370       15  4.935000  24  12
# 7      4  Mitchell Santner   92.4        4   449       16  4.958000  24  14
# 8     24     Glenn Maxwell   68.3        1   330        6  5.041250  22   5
# 9     19     Kagiso Rabada   72.5        7   364       13  5.060000  36  11
#
#    wd
# 0  22
# 1   4
# 2   2
# 3  12
# 4  13
# 5   3
# 6   8
# 7   5
# 8   3
# 9   7

# %%
plt.figure(figsize=(8,4))
plt.plot(best_economy['player'], best_economy['run_rate'], linestyle='--', marker='o', color='red')
plt.grid()
plt.xticks(rotation=90)
plt.title('Bowlers with best economy rate')
plt.xlabel('Players')
plt.ylabel('Economy rate')
plt.show()

# %% [markdown]
# # Top 30 bowlers conceded most runs.

# %%
temp = df_players.sort_values(by='runs', ascending=False).reset_index()

# %%
most_runs_conceded = temp[:30]

# %%
plt.figure(figsize=(12,4))
sns.barplot(data=most_runs_conceded, x='player', y='runs', palette='viridis')
plt.title('Most runs conceded by bowlers')
plt.xticks(rotation=90)
plt.show()
